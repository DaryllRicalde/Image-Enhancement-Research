# %%
import numpy as np 
import cv2 as cv 
import math
from matplotlib import pyplot as plt 
from matplotlib import *
import sys

# %%
def imageHistogram(referenceImage):
    img = cv.imread(referenceImage,0)
    plt.hist(img.ravel(),256,[0,256]); plt.show()

# %%
imageHistogram('images/hand.jpg')

# %%
img = cv.imread("images/bwdog.jpg",0)
if img is None:
    sys.exit("Could not read the image")
equ = cv.equalizeHist(img)
res = np.hstack((img,equ)) #stacking images side-by-side
cv.imwrite('enhanced.png',res)
cv.imwrite('contrast.png',equ)
# Out:
# True

# %%
original = cv.imread("images/bwdog.jpg")
contrast = cv.imread("contrast.png",1)
def psnr(img1, img2):
    mse = numpy.mean( (img1 - img2) ** 2 )
    if mse == 0:
        return 100
    PIXEL_MAX = 255.0
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

d=psnr(original,contrast)
print(d)
# Out:
# 28.345727507084405
